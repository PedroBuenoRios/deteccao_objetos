# %%
import torch
import os
import glob
import cv2 as cv

TRAIN = True
EPOCHS = 25

# %%
def download_file(url, nome):
    url = url
    if not os.path.exists(nome):
        file = requests.get(url)
        open(nome, 'wb').write(file.content)
    else:
        print('Arquivo já existe, pulando o download')

# %%
def set_res_dir():
    # Directory to store results
    res_dir_count = len(glob.glob('runs/train/*'))
    print(f"Current number of result directories: {res_dir_count}")
    if TRAIN:
        RES_DIR = f"results_{res_dir_count+1}"
        print(RES_DIR)
    else:
        RES_DIR = f"results_{res_dir_count}"
    return RES_DIR

# %%
# !pip install roboflow

from roboflow import Roboflow

if not os.path.exists('Dados_RPG-1'):
    rf = Roboflow(api_key="nc0bgygPzfvks88x2Dsv")
    project = rf.workspace("ic-xo5gl").project("dados_rpg")
    dataset = project.version(1).download("yolov5")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Dados_RPG-1 in yolov5pytorch:: 100%|███████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 7924.58it/s]

# %%
if not os.path.exists('yolov5'):
    # !git clone https://github.com//ultralytics/yolov5.git
        
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14253, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 14253 (delta 0), reused 2 (delta 0), pack-reused 14245
# Receiving objects: 100% (14253/14253), 13.57 MiB | 5.48 MiB/s, done.
# Resolving deltas: 100% (9810/9810), done.
# /home/pedro/Documentos/Dev/IC/yolov5/yolov5
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
RES_DIR = set_res_dir()
# %cd yolov5
# !python train.py --data ./Dados_RPG-1/data.yaml --weights yolov5s.pt --img 640 --epochs 25 --batch-size 2 --name {RES_DIR}
# Out:
# Current number of result directories: 0
# results_1
# /home/pedro/Documentos/Dev/IC/yolov5
# train: weights=yolov5s.pt, cfg=, data=./Dados_RPG-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=results_1, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-10-g10c025d Python-3.10.8 torch-1.13.0+cu117 CPU
#
# ...

# %%
def show_resultados_validos(RES_DIR):
    # !ls runs/train/{RES_DIR}
    EXP_PATH = f'runs/train/{RES_DIR}'
    pred_imagens_validacao = glob.glob(f'{EXP_PATH}/*_pre.jpg')
    printf(pred_imagens_validacao)
    for pred_imagem in pre_imagens_validacao:
        imagem = cv.imread(pred_imagem)
        plt.figure(figsize=(19,16))
        plt.imshow(image[:,:,::-1])
        plt.axis('off')
        plt.show

# %%
show_resultados_validos(RES_DIR)
